# %%
import os

import pandas as pd

from andromeda_drop import drop_rows, drop_cols
from andromeda_trim import trim_top, trim_left, trim_bot

current_file = "data/fz10_2024_12.xlsx"  # <-------------------------------------------------

xls = pd.ExcelFile(current_file)
file_name = os.path.splitext(os.path.basename(current_file))[0]
parts = current_file.split("_")
date_str = f"{parts[-2]}-{parts[-1].split('.')[0]}"

df = pd.read_excel(
    current_file,
    sheet_name=xls.sheet_names[0],
    header=0,
    skiprows=0,
    usecols=None
)
xls.sheet_names
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 10
#       6 from andromeda_trim import trim_top, trim_left, trim_bot
#       8 current_file = "data/fz10_2024_12.xlsx"  # <-------------------------------------------------
# ---> 10 xls = pd.ExcelFile(current_file)
#      11 file_name = os.path.splitext(os.path.basename(current_file))[0]
#      12 parts = current_file.split("_")
#
# File ~\Desktop\DA\Jupyter\.venv\Lib\site-packages\pandas\io\excel\_base.py:1550, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1548     ext = "xls"
#    1549 else:
# -> 1550     ext = inspect_excel_format(
#    1551         content_or_path=path_or_buffer, storage_options=storage_options
#    1552     )
#    1553     if ext is None:
#    1554         raise ValueError(
# ...

# %%
df = trim_top(df)["Insgesamt"]
df = trim_left(df)["Marke"]
df = trim_bot(df)["SONSTIGE", False]

# %%
df = drop_rows(df)["ZUSAMMEN", "Marke", True]
df = drop_cols(df)["Jan.-Dezember 2024", "Anteil \nin %"]
df.reset_index()
df.head(20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = drop_rows(df)["ZUSAMMEN", "Marke", True]
#       2 df = drop_cols(df)["Jan.-Dezember 2024", "Anteil \nin %"]
#       3 df.reset_index()
#
# NameError: name 'drop_rows' is not defined
